# %% [markdown]
# # Food CNN

# %%
import tensorflow as tf
import glob

# %%
import pandas as pd 
import os
import numpy as np 
import cv2
from tensorflow.keras.preprocessing import image 
from tensorflow.keras import regularizers, utils

import numpy as np 
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten 
from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, BatchNormalization, AveragePooling2D
from tensorflow.keras.optimizers import Adam
from keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau


from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from tensorflow.keras.utils import to_categorical
from skimage.segmentation import mark_boundaries 
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# ## Load data and Augment

# %%
datagen=ImageDataGenerator(rotation_range=40,
        width_shift_range=0.2,
        height_shift_range=0.2,
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True,
        fill_mode='nearest',
        validation_split=0.1,)

crop_train_generator=datagen.flow_from_directory(
    directory="./UECFOOD100_CROP/train_crop",
    batch_size=32,
    seed=42,
    shuffle=True,
    class_mode="categorical",
    target_size=(128,128),
    subset='training')


crop_val_generator=datagen.flow_from_directory(
    directory="./UECFOOD100_CROP/train_crop",
    batch_size=32,
    seed=42,
    shuffle=True,
    class_mode="categorical",
    target_size=(128,128),
    
    subset='validation')
# Out:
# Found 10562 images belonging to 100 classes.
# Found 1126 images belonging to 100 classes.

# %% [markdown]
# ## Create Food Classifier
#
# Use transfer learning with InceptionV3 as the base model

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.xception import Xception
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.applications.inception_resnet_v2 import InceptionResNetV2
from tensorflow.keras.applications import ResNet50 
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.applications.mobilenet_v2 import MobileNetV2


from tensorflow.keras import models
from tensorflow.keras.layers import Input
import tensorflow as tf
import keras_metrics as km

# %%
optimizer = Adam(lr = .001)

inception = InceptionResNetV2(weights='imagenet', include_top=False)

for layer in inception.layers:
    layer.trainable = False
    
x = inception.output
x = GlobalAveragePooling2D()(x)
x = BatchNormalization()(x)
x = Dense(2048,activation='relu')(x)
x = Dropout(0.2)(x)
predictions = Dense(100,kernel_regularizer=regularizers.l2(0.005), activation='softmax')(x)
model = models.Model(inputs=inception.input, outputs=predictions)
model.compile(loss = 'categorical_crossentropy', optimizer = optimizer, metrics = ['accuracy', 'top_k_categorical_accuracy','binary_accuracy', km.binary_precision(),
                                                                             km.binary_recall()])
model.summary()

#early stopping to monitor the validation loss and avoid overfitting
early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10, restore_best_weights=True)

#reducing learning rate on plateau
rlrop = ReduceLROnPlateau(monitor='val_loss', mode='min', patience= 5, factor= 0.5, min_lr= 1e-6, verbose=1)
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, None, None,  0
# __________________________________________________________________________________________________
# conv2d_406 (Conv2D)             (None, None, None, 3 864         input_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_408 (BatchN (None, None, None, 3 96          conv2d_406[0][0]
# __________________________________________________________________________________________________
# activation_406 (Activation)     (None, None, None, 3 0           batch_normalization_408[0][0]
# __________________________________________________________________________________________________
# conv2d_407 (Conv2D)             (None, None, None, 3 9216        activation_406[0][0]
# __________________________________________________________________________________________________
# batch_normalization_409 (BatchN (None, None, None, 3 96          conv2d_407[0][0]
# __________________________________________________________________________________________________
# activation_407 (Activation)     (None, None, None, 3 0           batch_normalization_409[0][0]
# __________________________________________________________________________________________________
# conv2d_408 (Conv2D)             (None, None, None, 6 18432       activation_407[0][0]
# __________________________________________________________________________________________________
# batch_normalization_410 (BatchN (None, None, None, 6 192         conv2d_408[0][0]
# __________________________________________________________________________________________________
# activation_408 (Activation)     (None, None, None, 6 0           batch_normalization_410[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, None, None, 6 0           activation_408[0][0]
# __________________________________________________________________________________________________
# conv2d_409 (Conv2D)             (None, None, None, 8 5120        max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_411 (BatchN (None, None, None, 8 240         conv2d_409[0][0]
# __________________________________________________________________________________________________
# activation_409 (Activation)     (None, None, None, 8 0           batch_normalization_411[0][0]
# __________________________________________________________________________________________________
# conv2d_410 (Conv2D)             (None, None, None, 1 138240      activation_409[0][0]
# __________________________________________________________________________________________________
# batch_normalization_412 (BatchN (None, None, None, 1 576         conv2d_410[0][0]
# __________________________________________________________________________________________________
# activation_410 (Activation)     (None, None, None, 1 0           batch_normalization_412[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, None, None, 1 0           activation_410[0][0]
# __________________________________________________________________________________________________
# conv2d_414 (Conv2D)             (None, None, None, 6 12288       max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_416 (BatchN (None, None, None, 6 192         conv2d_414[0][0]
# __________________________________________________________________________________________________
# activation_414 (Activation)     (None, None, None, 6 0           batch_normalization_416[0][0]
# __________________________________________________________________________________________________
# conv2d_412 (Conv2D)             (None, None, None, 4 9216        max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_415 (Conv2D)             (None, None, None, 9 55296       activation_414[0][0]
# __________________________________________________________________________________________________
# batch_normalization_414 (BatchN (None, None, None, 4 144         conv2d_412[0][0]
# __________________________________________________________________________________________________
# batch_normalization_417 (BatchN (None, None, None, 9 288         conv2d_415[0][0]
# __________________________________________________________________________________________________
# activation_412 (Activation)     (None, None, None, 4 0           batch_normalization_414[0][0]
# __________________________________________________________________________________________________
# activation_415 (Activation)     (None, None, None, 9 0           batch_normalization_417[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, None, None, 1 0           max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_411 (Conv2D)             (None, None, None, 9 18432       max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_413 (Conv2D)             (None, None, None, 6 76800       activation_412[0][0]
# __________________________________________________________________________________________________
# conv2d_416 (Conv2D)             (None, None, None, 9 82944       activation_415[0][0]
# __________________________________________________________________________________________________
# conv2d_417 (Conv2D)             (None, None, None, 6 12288       average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_413 (BatchN (None, None, None, 9 288         conv2d_411[0][0]
# __________________________________________________________________________________________________
# batch_normalization_415 (BatchN (None, None, None, 6 192         conv2d_413[0][0]
# __________________________________________________________________________________________________
# batch_normalization_418 (BatchN (None, None, None, 9 288         conv2d_416[0][0]
# __________________________________________________________________________________________________
# batch_normalization_419 (BatchN (None, None, None, 6 192         conv2d_417[0][0]
# __________________________________________________________________________________________________
# activation_411 (Activation)     (None, None, None, 9 0           batch_normalization_413[0][0]
# __________________________________________________________________________________________________
# activation_413 (Activation)     (None, None, None, 6 0           batch_normalization_415[0][0]
# __________________________________________________________________________________________________
# activation_416 (Activation)     (None, None, None, 9 0           batch_normalization_418[0][0]
# __________________________________________________________________________________________________
# activation_417 (Activation)     (None, None, None, 6 0           batch_normalization_419[0][0]
# __________________________________________________________________________________________________
# mixed_5b (Concatenate)          (None, None, None, 3 0           activation_411[0][0]
#                                                                  activation_413[0][0]
#                                                                  activation_416[0][0]
#                                                                  activation_417[0][0]
# __________________________________________________________________________________________________
# conv2d_421 (Conv2D)             (None, None, None, 3 10240       mixed_5b[0][0]
# __________________________________________________________________________________________________
# batch_normalization_423 (BatchN (None, None, None, 3 96          conv2d_421[0][0]
# __________________________________________________________________________________________________
# activation_421 (Activation)     (None, None, None, 3 0           batch_normalization_423[0][0]
# __________________________________________________________________________________________________
# conv2d_419 (Conv2D)             (None, None, None, 3 10240       mixed_5b[0][0]
# __________________________________________________________________________________________________
# conv2d_422 (Conv2D)             (None, None, None, 4 13824       activation_421[0][0]
# __________________________________________________________________________________________________
# batch_normalization_421 (BatchN (None, None, None, 3 96          conv2d_419[0][0]
# __________________________________________________________________________________________________
# batch_normalization_424 (BatchN (None, None, None, 4 144         conv2d_422[0][0]
# __________________________________________________________________________________________________
# activation_419 (Activation)     (None, None, None, 3 0           batch_normalization_421[0][0]
# __________________________________________________________________________________________________
# activation_422 (Activation)     (None, None, None, 4 0           batch_normalization_424[0][0]
# __________________________________________________________________________________________________
# conv2d_418 (Conv2D)             (None, None, None, 3 10240       mixed_5b[0][0]
# __________________________________________________________________________________________________
# conv2d_420 (Conv2D)             (None, None, None, 3 9216        activation_419[0][0]
# __________________________________________________________________________________________________
# conv2d_423 (Conv2D)             (None, None, None, 6 27648       activation_422[0][0]
# __________________________________________________________________________________________________
# batch_normalization_420 (BatchN (None, None, None, 3 96          conv2d_418[0][0]
# __________________________________________________________________________________________________
# batch_normalization_422 (BatchN (None, None, None, 3 96          conv2d_420[0][0]
# __________________________________________________________________________________________________
# batch_normalization_425 (BatchN (None, None, None, 6 192         conv2d_423[0][0]
# __________________________________________________________________________________________________
# activation_418 (Activation)     (None, None, None, 3 0           batch_normalization_420[0][0]
# __________________________________________________________________________________________________
# activation_420 (Activation)     (None, None, None, 3 0           batch_normalization_422[0][0]
# __________________________________________________________________________________________________
# activation_423 (Activation)     (None, None, None, 6 0           batch_normalization_425[0][0]
# __________________________________________________________________________________________________
# block35_1_mixed (Concatenate)   (None, None, None, 1 0           activation_418[0][0]
#                                                                  activation_420[0][0]
#                                                                  activation_423[0][0]
# __________________________________________________________________________________________________
# block35_1_conv (Conv2D)         (None, None, None, 3 41280       block35_1_mixed[0][0]
# __________________________________________________________________________________________________
# block35_1 (Lambda)              (None, None, None, 3 0           mixed_5b[0][0]
#                                                                  block35_1_conv[0][0]
# __________________________________________________________________________________________________
# block35_1_ac (Activation)       (None, None, None, 3 0           block35_1[0][0]
# __________________________________________________________________________________________________
# conv2d_427 (Conv2D)             (None, None, None, 3 10240       block35_1_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_429 (BatchN (None, None, None, 3 96          conv2d_427[0][0]
# __________________________________________________________________________________________________
# activation_427 (Activation)     (None, None, None, 3 0           batch_normalization_429[0][0]
# __________________________________________________________________________________________________
# conv2d_425 (Conv2D)             (None, None, None, 3 10240       block35_1_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_428 (Conv2D)             (None, None, None, 4 13824       activation_427[0][0]
# __________________________________________________________________________________________________
# batch_normalization_427 (BatchN (None, None, None, 3 96          conv2d_425[0][0]
# __________________________________________________________________________________________________
# batch_normalization_430 (BatchN (None, None, None, 4 144         conv2d_428[0][0]
# __________________________________________________________________________________________________
# activation_425 (Activation)     (None, None, None, 3 0           batch_normalization_427[0][0]
# __________________________________________________________________________________________________
# activation_428 (Activation)     (None, None, None, 4 0           batch_normalization_430[0][0]
# __________________________________________________________________________________________________
# conv2d_424 (Conv2D)             (None, None, None, 3 10240       block35_1_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_426 (Conv2D)             (None, None, None, 3 9216        activation_425[0][0]
# __________________________________________________________________________________________________
# conv2d_429 (Conv2D)             (None, None, None, 6 27648       activation_428[0][0]
# __________________________________________________________________________________________________
# batch_normalization_426 (BatchN (None, None, None, 3 96          conv2d_424[0][0]
# __________________________________________________________________________________________________
# batch_normalization_428 (BatchN (None, None, None, 3 96          conv2d_426[0][0]
# __________________________________________________________________________________________________
# batch_normalization_431 (BatchN (None, None, None, 6 192         conv2d_429[0][0]
# __________________________________________________________________________________________________
# activation_424 (Activation)     (None, None, None, 3 0           batch_normalization_426[0][0]
# __________________________________________________________________________________________________
# activation_426 (Activation)     (None, None, None, 3 0           batch_normalization_428[0][0]
# __________________________________________________________________________________________________
# activation_429 (Activation)     (None, None, None, 6 0           batch_normalization_431[0][0]
# __________________________________________________________________________________________________
# block35_2_mixed (Concatenate)   (None, None, None, 1 0           activation_424[0][0]
#                                                                  activation_426[0][0]
#                                                                  activation_429[0][0]
# __________________________________________________________________________________________________
# block35_2_conv (Conv2D)         (None, None, None, 3 41280       block35_2_mixed[0][0]
# __________________________________________________________________________________________________
# block35_2 (Lambda)              (None, None, None, 3 0           block35_1_ac[0][0]
#                                                                  block35_2_conv[0][0]
# __________________________________________________________________________________________________
# block35_2_ac (Activation)       (None, None, None, 3 0           block35_2[0][0]
# __________________________________________________________________________________________________
# conv2d_433 (Conv2D)             (None, None, None, 3 10240       block35_2_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_435 (BatchN (None, None, None, 3 96          conv2d_433[0][0]
# __________________________________________________________________________________________________
# activation_433 (Activation)     (None, None, None, 3 0           batch_normalization_435[0][0]
# __________________________________________________________________________________________________
# conv2d_431 (Conv2D)             (None, None, None, 3 10240       block35_2_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_434 (Conv2D)             (None, None, None, 4 13824       activation_433[0][0]
# __________________________________________________________________________________________________
# batch_normalization_433 (BatchN (None, None, None, 3 96          conv2d_431[0][0]
# __________________________________________________________________________________________________
# batch_normalization_436 (BatchN (None, None, None, 4 144         conv2d_434[0][0]
# __________________________________________________________________________________________________
# activation_431 (Activation)     (None, None, None, 3 0           batch_normalization_433[0][0]
# __________________________________________________________________________________________________
# activation_434 (Activation)     (None, None, None, 4 0           batch_normalization_436[0][0]
# __________________________________________________________________________________________________
# conv2d_430 (Conv2D)             (None, None, None, 3 10240       block35_2_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_432 (Conv2D)             (None, None, None, 3 9216        activation_431[0][0]
# __________________________________________________________________________________________________
# conv2d_435 (Conv2D)             (None, None, None, 6 27648       activation_434[0][0]
# __________________________________________________________________________________________________
# batch_normalization_432 (BatchN (None, None, None, 3 96          conv2d_430[0][0]
# __________________________________________________________________________________________________
# batch_normalization_434 (BatchN (None, None, None, 3 96          conv2d_432[0][0]
# __________________________________________________________________________________________________
# batch_normalization_437 (BatchN (None, None, None, 6 192         conv2d_435[0][0]
# __________________________________________________________________________________________________
# activation_430 (Activation)     (None, None, None, 3 0           batch_normalization_432[0][0]
# __________________________________________________________________________________________________
# activation_432 (Activation)     (None, None, None, 3 0           batch_normalization_434[0][0]
# __________________________________________________________________________________________________
# activation_435 (Activation)     (None, None, None, 6 0           batch_normalization_437[0][0]
# __________________________________________________________________________________________________
# block35_3_mixed (Concatenate)   (None, None, None, 1 0           activation_430[0][0]
#                                                                  activation_432[0][0]
#                                                                  activation_435[0][0]
# __________________________________________________________________________________________________
# block35_3_conv (Conv2D)         (None, None, None, 3 41280       block35_3_mixed[0][0]
# __________________________________________________________________________________________________
# block35_3 (Lambda)              (None, None, None, 3 0           block35_2_ac[0][0]
#                                                                  block35_3_conv[0][0]
# __________________________________________________________________________________________________
# block35_3_ac (Activation)       (None, None, None, 3 0           block35_3[0][0]
# __________________________________________________________________________________________________
# conv2d_439 (Conv2D)             (None, None, None, 3 10240       block35_3_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_441 (BatchN (None, None, None, 3 96          conv2d_439[0][0]
# __________________________________________________________________________________________________
# activation_439 (Activation)     (None, None, None, 3 0           batch_normalization_441[0][0]
# __________________________________________________________________________________________________
# conv2d_437 (Conv2D)             (None, None, None, 3 10240       block35_3_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_440 (Conv2D)             (None, None, None, 4 13824       activation_439[0][0]
# __________________________________________________________________________________________________
# batch_normalization_439 (BatchN (None, None, None, 3 96          conv2d_437[0][0]
# __________________________________________________________________________________________________
# batch_normalization_442 (BatchN (None, None, None, 4 144         conv2d_440[0][0]
# __________________________________________________________________________________________________
# activation_437 (Activation)     (None, None, None, 3 0           batch_normalization_439[0][0]
# __________________________________________________________________________________________________
# activation_440 (Activation)     (None, None, None, 4 0           batch_normalization_442[0][0]
# __________________________________________________________________________________________________
# conv2d_436 (Conv2D)             (None, None, None, 3 10240       block35_3_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_438 (Conv2D)             (None, None, None, 3 9216        activation_437[0][0]
# __________________________________________________________________________________________________
# conv2d_441 (Conv2D)             (None, None, None, 6 27648       activation_440[0][0]
# __________________________________________________________________________________________________
# batch_normalization_438 (BatchN (None, None, None, 3 96          conv2d_436[0][0]
# __________________________________________________________________________________________________
# batch_normalization_440 (BatchN (None, None, None, 3 96          conv2d_438[0][0]
# __________________________________________________________________________________________________
# batch_normalization_443 (BatchN (None, None, None, 6 192         conv2d_441[0][0]
# __________________________________________________________________________________________________
# activation_436 (Activation)     (None, None, None, 3 0           batch_normalization_438[0][0]
# __________________________________________________________________________________________________
# activation_438 (Activation)     (None, None, None, 3 0           batch_normalization_440[0][0]
# __________________________________________________________________________________________________
# activation_441 (Activation)     (None, None, None, 6 0           batch_normalization_443[0][0]
# __________________________________________________________________________________________________
# block35_4_mixed (Concatenate)   (None, None, None, 1 0           activation_436[0][0]
#                                                                  activation_438[0][0]
#                                                                  activation_441[0][0]
# __________________________________________________________________________________________________
# block35_4_conv (Conv2D)         (None, None, None, 3 41280       block35_4_mixed[0][0]
# __________________________________________________________________________________________________
# block35_4 (Lambda)              (None, None, None, 3 0           block35_3_ac[0][0]
#                                                                  block35_4_conv[0][0]
# __________________________________________________________________________________________________
# block35_4_ac (Activation)       (None, None, None, 3 0           block35_4[0][0]
# __________________________________________________________________________________________________
# conv2d_445 (Conv2D)             (None, None, None, 3 10240       block35_4_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_447 (BatchN (None, None, None, 3 96          conv2d_445[0][0]
# __________________________________________________________________________________________________
# activation_445 (Activation)     (None, None, None, 3 0           batch_normalization_447[0][0]
# __________________________________________________________________________________________________
# conv2d_443 (Conv2D)             (None, None, None, 3 10240       block35_4_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_446 (Conv2D)             (None, None, None, 4 13824       activation_445[0][0]
# __________________________________________________________________________________________________
# batch_normalization_445 (BatchN (None, None, None, 3 96          conv2d_443[0][0]
# __________________________________________________________________________________________________
# batch_normalization_448 (BatchN (None, None, None, 4 144         conv2d_446[0][0]
# __________________________________________________________________________________________________
# activation_443 (Activation)     (None, None, None, 3 0           batch_normalization_445[0][0]
# __________________________________________________________________________________________________
# activation_446 (Activation)     (None, None, None, 4 0           batch_normalization_448[0][0]
# __________________________________________________________________________________________________
# conv2d_442 (Conv2D)             (None, None, None, 3 10240       block35_4_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_444 (Conv2D)             (None, None, None, 3 9216        activation_443[0][0]
# __________________________________________________________________________________________________
# conv2d_447 (Conv2D)             (None, None, None, 6 27648       activation_446[0][0]
# __________________________________________________________________________________________________
# batch_normalization_444 (BatchN (None, None, None, 3 96          conv2d_442[0][0]
# __________________________________________________________________________________________________
# batch_normalization_446 (BatchN (None, None, None, 3 96          conv2d_444[0][0]
# __________________________________________________________________________________________________
# batch_normalization_449 (BatchN (None, None, None, 6 192         conv2d_447[0][0]
# __________________________________________________________________________________________________
# activation_442 (Activation)     (None, None, None, 3 0           batch_normalization_444[0][0]
# __________________________________________________________________________________________________
# activation_444 (Activation)     (None, None, None, 3 0           batch_normalization_446[0][0]
# __________________________________________________________________________________________________
# activation_447 (Activation)     (None, None, None, 6 0           batch_normalization_449[0][0]
# __________________________________________________________________________________________________
# block35_5_mixed (Concatenate)   (None, None, None, 1 0           activation_442[0][0]
#                                                                  activation_444[0][0]
#                                                                  activation_447[0][0]
# __________________________________________________________________________________________________
# block35_5_conv (Conv2D)         (None, None, None, 3 41280       block35_5_mixed[0][0]
# __________________________________________________________________________________________________
# block35_5 (Lambda)              (None, None, None, 3 0           block35_4_ac[0][0]
#                                                                  block35_5_conv[0][0]
# __________________________________________________________________________________________________
# block35_5_ac (Activation)       (None, None, None, 3 0           block35_5[0][0]
# __________________________________________________________________________________________________
# conv2d_451 (Conv2D)             (None, None, None, 3 10240       block35_5_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_453 (BatchN (None, None, None, 3 96          conv2d_451[0][0]
# __________________________________________________________________________________________________
# activation_451 (Activation)     (None, None, None, 3 0           batch_normalization_453[0][0]
# __________________________________________________________________________________________________
# conv2d_449 (Conv2D)             (None, None, None, 3 10240       block35_5_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_452 (Conv2D)             (None, None, None, 4 13824       activation_451[0][0]
# __________________________________________________________________________________________________
# batch_normalization_451 (BatchN (None, None, None, 3 96          conv2d_449[0][0]
# __________________________________________________________________________________________________
# batch_normalization_454 (BatchN (None, None, None, 4 144         conv2d_452[0][0]
# __________________________________________________________________________________________________
# activation_449 (Activation)     (None, None, None, 3 0           batch_normalization_451[0][0]
# __________________________________________________________________________________________________
# activation_452 (Activation)     (None, None, None, 4 0           batch_normalization_454[0][0]
# __________________________________________________________________________________________________
# conv2d_448 (Conv2D)             (None, None, None, 3 10240       block35_5_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_450 (Conv2D)             (None, None, None, 3 9216        activation_449[0][0]
# __________________________________________________________________________________________________
# conv2d_453 (Conv2D)             (None, None, None, 6 27648       activation_452[0][0]
# __________________________________________________________________________________________________
# batch_normalization_450 (BatchN (None, None, None, 3 96          conv2d_448[0][0]
# __________________________________________________________________________________________________
# batch_normalization_452 (BatchN (None, None, None, 3 96          conv2d_450[0][0]
# __________________________________________________________________________________________________
# batch_normalization_455 (BatchN (None, None, None, 6 192         conv2d_453[0][0]
# __________________________________________________________________________________________________
# activation_448 (Activation)     (None, None, None, 3 0           batch_normalization_450[0][0]
# __________________________________________________________________________________________________
# activation_450 (Activation)     (None, None, None, 3 0           batch_normalization_452[0][0]
# __________________________________________________________________________________________________
# activation_453 (Activation)     (None, None, None, 6 0           batch_normalization_455[0][0]
# __________________________________________________________________________________________________
# block35_6_mixed (Concatenate)   (None, None, None, 1 0           activation_448[0][0]
#                                                                  activation_450[0][0]
#                                                                  activation_453[0][0]
# __________________________________________________________________________________________________
# block35_6_conv (Conv2D)         (None, None, None, 3 41280       block35_6_mixed[0][0]
# __________________________________________________________________________________________________
# block35_6 (Lambda)              (None, None, None, 3 0           block35_5_ac[0][0]
#                                                                  block35_6_conv[0][0]
# __________________________________________________________________________________________________
# block35_6_ac (Activation)       (None, None, None, 3 0           block35_6[0][0]
# __________________________________________________________________________________________________
# conv2d_457 (Conv2D)             (None, None, None, 3 10240       block35_6_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_459 (BatchN (None, None, None, 3 96          conv2d_457[0][0]
# __________________________________________________________________________________________________
# activation_457 (Activation)     (None, None, None, 3 0           batch_normalization_459[0][0]
# __________________________________________________________________________________________________
# conv2d_455 (Conv2D)             (None, None, None, 3 10240       block35_6_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_458 (Conv2D)             (None, None, None, 4 13824       activation_457[0][0]
# __________________________________________________________________________________________________
# batch_normalization_457 (BatchN (None, None, None, 3 96          conv2d_455[0][0]
# __________________________________________________________________________________________________
# batch_normalization_460 (BatchN (None, None, None, 4 144         conv2d_458[0][0]
# __________________________________________________________________________________________________
# activation_455 (Activation)     (None, None, None, 3 0           batch_normalization_457[0][0]
# __________________________________________________________________________________________________
# activation_458 (Activation)     (None, None, None, 4 0           batch_normalization_460[0][0]
# __________________________________________________________________________________________________
# conv2d_454 (Conv2D)             (None, None, None, 3 10240       block35_6_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_456 (Conv2D)             (None, None, None, 3 9216        activation_455[0][0]
# __________________________________________________________________________________________________
# conv2d_459 (Conv2D)             (None, None, None, 6 27648       activation_458[0][0]
# __________________________________________________________________________________________________
# batch_normalization_456 (BatchN (None, None, None, 3 96          conv2d_454[0][0]
# __________________________________________________________________________________________________
# batch_normalization_458 (BatchN (None, None, None, 3 96          conv2d_456[0][0]
# __________________________________________________________________________________________________
# batch_normalization_461 (BatchN (None, None, None, 6 192         conv2d_459[0][0]
# __________________________________________________________________________________________________
# activation_454 (Activation)     (None, None, None, 3 0           batch_normalization_456[0][0]
# __________________________________________________________________________________________________
# activation_456 (Activation)     (None, None, None, 3 0           batch_normalization_458[0][0]
# __________________________________________________________________________________________________
# activation_459 (Activation)     (None, None, None, 6 0           batch_normalization_461[0][0]
# __________________________________________________________________________________________________
# block35_7_mixed (Concatenate)   (None, None, None, 1 0           activation_454[0][0]
#                                                                  activation_456[0][0]
#                                                                  activation_459[0][0]
# __________________________________________________________________________________________________
# block35_7_conv (Conv2D)         (None, None, None, 3 41280       block35_7_mixed[0][0]
# __________________________________________________________________________________________________
# block35_7 (Lambda)              (None, None, None, 3 0           block35_6_ac[0][0]
#                                                                  block35_7_conv[0][0]
# __________________________________________________________________________________________________
# block35_7_ac (Activation)       (None, None, None, 3 0           block35_7[0][0]
# __________________________________________________________________________________________________
# conv2d_463 (Conv2D)             (None, None, None, 3 10240       block35_7_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_465 (BatchN (None, None, None, 3 96          conv2d_463[0][0]
# __________________________________________________________________________________________________
# activation_463 (Activation)     (None, None, None, 3 0           batch_normalization_465[0][0]
# __________________________________________________________________________________________________
# conv2d_461 (Conv2D)             (None, None, None, 3 10240       block35_7_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_464 (Conv2D)             (None, None, None, 4 13824       activation_463[0][0]
# __________________________________________________________________________________________________
# batch_normalization_463 (BatchN (None, None, None, 3 96          conv2d_461[0][0]
# __________________________________________________________________________________________________
# batch_normalization_466 (BatchN (None, None, None, 4 144         conv2d_464[0][0]
# __________________________________________________________________________________________________
# activation_461 (Activation)     (None, None, None, 3 0           batch_normalization_463[0][0]
# __________________________________________________________________________________________________
# activation_464 (Activation)     (None, None, None, 4 0           batch_normalization_466[0][0]
# __________________________________________________________________________________________________
# conv2d_460 (Conv2D)             (None, None, None, 3 10240       block35_7_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_462 (Conv2D)             (None, None, None, 3 9216        activation_461[0][0]
# __________________________________________________________________________________________________
# conv2d_465 (Conv2D)             (None, None, None, 6 27648       activation_464[0][0]
# __________________________________________________________________________________________________
# batch_normalization_462 (BatchN (None, None, None, 3 96          conv2d_460[0][0]
# __________________________________________________________________________________________________
# batch_normalization_464 (BatchN (None, None, None, 3 96          conv2d_462[0][0]
# __________________________________________________________________________________________________
# batch_normalization_467 (BatchN (None, None, None, 6 192         conv2d_465[0][0]
# __________________________________________________________________________________________________
# activation_460 (Activation)     (None, None, None, 3 0           batch_normalization_462[0][0]
# __________________________________________________________________________________________________
# activation_462 (Activation)     (None, None, None, 3 0           batch_normalization_464[0][0]
# __________________________________________________________________________________________________
# activation_465 (Activation)     (None, None, None, 6 0           batch_normalization_467[0][0]
# __________________________________________________________________________________________________
# block35_8_mixed (Concatenate)   (None, None, None, 1 0           activation_460[0][0]
#                                                                  activation_462[0][0]
#                                                                  activation_465[0][0]
# __________________________________________________________________________________________________
# block35_8_conv (Conv2D)         (None, None, None, 3 41280       block35_8_mixed[0][0]
# __________________________________________________________________________________________________
# block35_8 (Lambda)              (None, None, None, 3 0           block35_7_ac[0][0]
#                                                                  block35_8_conv[0][0]
# __________________________________________________________________________________________________
# block35_8_ac (Activation)       (None, None, None, 3 0           block35_8[0][0]
# __________________________________________________________________________________________________
# conv2d_469 (Conv2D)             (None, None, None, 3 10240       block35_8_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_471 (BatchN (None, None, None, 3 96          conv2d_469[0][0]
# __________________________________________________________________________________________________
# activation_469 (Activation)     (None, None, None, 3 0           batch_normalization_471[0][0]
# __________________________________________________________________________________________________
# conv2d_467 (Conv2D)             (None, None, None, 3 10240       block35_8_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_470 (Conv2D)             (None, None, None, 4 13824       activation_469[0][0]
# __________________________________________________________________________________________________
# batch_normalization_469 (BatchN (None, None, None, 3 96          conv2d_467[0][0]
# __________________________________________________________________________________________________
# batch_normalization_472 (BatchN (None, None, None, 4 144         conv2d_470[0][0]
# __________________________________________________________________________________________________
# activation_467 (Activation)     (None, None, None, 3 0           batch_normalization_469[0][0]
# __________________________________________________________________________________________________
# activation_470 (Activation)     (None, None, None, 4 0           batch_normalization_472[0][0]
# __________________________________________________________________________________________________
# conv2d_466 (Conv2D)             (None, None, None, 3 10240       block35_8_ac[0][0]
# __________________________________________________________________________________________________
# ...
#                                                                  activation_592[0][0]
# __________________________________________________________________________________________________
# block8_6_conv (Conv2D)          (None, None, None, 2 933920      block8_6_mixed[0][0]
# __________________________________________________________________________________________________
# block8_6 (Lambda)               (None, None, None, 2 0           block8_5_ac[0][0]
#                                                                  block8_6_conv[0][0]
# __________________________________________________________________________________________________
# block8_6_ac (Activation)        (None, None, None, 2 0           block8_6[0][0]
# __________________________________________________________________________________________________
# conv2d_594 (Conv2D)             (None, None, None, 1 399360      block8_6_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_596 (BatchN (None, None, None, 1 576         conv2d_594[0][0]
# __________________________________________________________________________________________________
# activation_594 (Activation)     (None, None, None, 1 0           batch_normalization_596[0][0]
# __________________________________________________________________________________________________
# conv2d_595 (Conv2D)             (None, None, None, 2 129024      activation_594[0][0]
# __________________________________________________________________________________________________
# batch_normalization_597 (BatchN (None, None, None, 2 672         conv2d_595[0][0]
# __________________________________________________________________________________________________
# activation_595 (Activation)     (None, None, None, 2 0           batch_normalization_597[0][0]
# __________________________________________________________________________________________________
# conv2d_593 (Conv2D)             (None, None, None, 1 399360      block8_6_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_596 (Conv2D)             (None, None, None, 2 172032      activation_595[0][0]
# __________________________________________________________________________________________________
# batch_normalization_595 (BatchN (None, None, None, 1 576         conv2d_593[0][0]
# __________________________________________________________________________________________________
# batch_normalization_598 (BatchN (None, None, None, 2 768         conv2d_596[0][0]
# __________________________________________________________________________________________________
# activation_593 (Activation)     (None, None, None, 1 0           batch_normalization_595[0][0]
# __________________________________________________________________________________________________
# activation_596 (Activation)     (None, None, None, 2 0           batch_normalization_598[0][0]
# __________________________________________________________________________________________________
# block8_7_mixed (Concatenate)    (None, None, None, 4 0           activation_593[0][0]
#                                                                  activation_596[0][0]
# __________________________________________________________________________________________________
# block8_7_conv (Conv2D)          (None, None, None, 2 933920      block8_7_mixed[0][0]
# __________________________________________________________________________________________________
# block8_7 (Lambda)               (None, None, None, 2 0           block8_6_ac[0][0]
#                                                                  block8_7_conv[0][0]
# __________________________________________________________________________________________________
# block8_7_ac (Activation)        (None, None, None, 2 0           block8_7[0][0]
# __________________________________________________________________________________________________
# conv2d_598 (Conv2D)             (None, None, None, 1 399360      block8_7_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_600 (BatchN (None, None, None, 1 576         conv2d_598[0][0]
# __________________________________________________________________________________________________
# activation_598 (Activation)     (None, None, None, 1 0           batch_normalization_600[0][0]
# __________________________________________________________________________________________________
# conv2d_599 (Conv2D)             (None, None, None, 2 129024      activation_598[0][0]
# __________________________________________________________________________________________________
# batch_normalization_601 (BatchN (None, None, None, 2 672         conv2d_599[0][0]
# __________________________________________________________________________________________________
# activation_599 (Activation)     (None, None, None, 2 0           batch_normalization_601[0][0]
# __________________________________________________________________________________________________
# conv2d_597 (Conv2D)             (None, None, None, 1 399360      block8_7_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_600 (Conv2D)             (None, None, None, 2 172032      activation_599[0][0]
# __________________________________________________________________________________________________
# batch_normalization_599 (BatchN (None, None, None, 1 576         conv2d_597[0][0]
# __________________________________________________________________________________________________
# batch_normalization_602 (BatchN (None, None, None, 2 768         conv2d_600[0][0]
# __________________________________________________________________________________________________
# activation_597 (Activation)     (None, None, None, 1 0           batch_normalization_599[0][0]
# __________________________________________________________________________________________________
# activation_600 (Activation)     (None, None, None, 2 0           batch_normalization_602[0][0]
# __________________________________________________________________________________________________
# block8_8_mixed (Concatenate)    (None, None, None, 4 0           activation_597[0][0]
#                                                                  activation_600[0][0]
# __________________________________________________________________________________________________
# block8_8_conv (Conv2D)          (None, None, None, 2 933920      block8_8_mixed[0][0]
# __________________________________________________________________________________________________
# block8_8 (Lambda)               (None, None, None, 2 0           block8_7_ac[0][0]
#                                                                  block8_8_conv[0][0]
# __________________________________________________________________________________________________
# block8_8_ac (Activation)        (None, None, None, 2 0           block8_8[0][0]
# __________________________________________________________________________________________________
# conv2d_602 (Conv2D)             (None, None, None, 1 399360      block8_8_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_604 (BatchN (None, None, None, 1 576         conv2d_602[0][0]
# __________________________________________________________________________________________________
# activation_602 (Activation)     (None, None, None, 1 0           batch_normalization_604[0][0]
# __________________________________________________________________________________________________
# conv2d_603 (Conv2D)             (None, None, None, 2 129024      activation_602[0][0]
# __________________________________________________________________________________________________
# batch_normalization_605 (BatchN (None, None, None, 2 672         conv2d_603[0][0]
# __________________________________________________________________________________________________
# activation_603 (Activation)     (None, None, None, 2 0           batch_normalization_605[0][0]
# __________________________________________________________________________________________________
# conv2d_601 (Conv2D)             (None, None, None, 1 399360      block8_8_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_604 (Conv2D)             (None, None, None, 2 172032      activation_603[0][0]
# __________________________________________________________________________________________________
# batch_normalization_603 (BatchN (None, None, None, 1 576         conv2d_601[0][0]
# __________________________________________________________________________________________________
# batch_normalization_606 (BatchN (None, None, None, 2 768         conv2d_604[0][0]
# __________________________________________________________________________________________________
# activation_601 (Activation)     (None, None, None, 1 0           batch_normalization_603[0][0]
# __________________________________________________________________________________________________
# activation_604 (Activation)     (None, None, None, 2 0           batch_normalization_606[0][0]
# __________________________________________________________________________________________________
# block8_9_mixed (Concatenate)    (None, None, None, 4 0           activation_601[0][0]
#                                                                  activation_604[0][0]
# __________________________________________________________________________________________________
# block8_9_conv (Conv2D)          (None, None, None, 2 933920      block8_9_mixed[0][0]
# __________________________________________________________________________________________________
# block8_9 (Lambda)               (None, None, None, 2 0           block8_8_ac[0][0]
#                                                                  block8_9_conv[0][0]
# __________________________________________________________________________________________________
# block8_9_ac (Activation)        (None, None, None, 2 0           block8_9[0][0]
# __________________________________________________________________________________________________
# conv2d_606 (Conv2D)             (None, None, None, 1 399360      block8_9_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_608 (BatchN (None, None, None, 1 576         conv2d_606[0][0]
# __________________________________________________________________________________________________
# activation_606 (Activation)     (None, None, None, 1 0           batch_normalization_608[0][0]
# __________________________________________________________________________________________________
# conv2d_607 (Conv2D)             (None, None, None, 2 129024      activation_606[0][0]
# __________________________________________________________________________________________________
# batch_normalization_609 (BatchN (None, None, None, 2 672         conv2d_607[0][0]
# __________________________________________________________________________________________________
# activation_607 (Activation)     (None, None, None, 2 0           batch_normalization_609[0][0]
# __________________________________________________________________________________________________
# conv2d_605 (Conv2D)             (None, None, None, 1 399360      block8_9_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_608 (Conv2D)             (None, None, None, 2 172032      activation_607[0][0]
# __________________________________________________________________________________________________
# batch_normalization_607 (BatchN (None, None, None, 1 576         conv2d_605[0][0]
# __________________________________________________________________________________________________
# batch_normalization_610 (BatchN (None, None, None, 2 768         conv2d_608[0][0]
# __________________________________________________________________________________________________
# activation_605 (Activation)     (None, None, None, 1 0           batch_normalization_607[0][0]
# __________________________________________________________________________________________________
# activation_608 (Activation)     (None, None, None, 2 0           batch_normalization_610[0][0]
# __________________________________________________________________________________________________
# block8_10_mixed (Concatenate)   (None, None, None, 4 0           activation_605[0][0]
#                                                                  activation_608[0][0]
# __________________________________________________________________________________________________
# block8_10_conv (Conv2D)         (None, None, None, 2 933920      block8_10_mixed[0][0]
# __________________________________________________________________________________________________
# block8_10 (Lambda)              (None, None, None, 2 0           block8_9_ac[0][0]
#                                                                  block8_10_conv[0][0]
# __________________________________________________________________________________________________
# conv_7b (Conv2D)                (None, None, None, 1 3194880     block8_10[0][0]
# __________________________________________________________________________________________________
# conv_7b_bn (BatchNormalization) (None, None, None, 1 4608        conv_7b[0][0]
# __________________________________________________________________________________________________
# conv_7b_ac (Activation)         (None, None, None, 1 0           conv_7b_bn[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2 (Glo (None, 1536)         0           conv_7b_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_611 (BatchN (None, 1536)         6144        global_average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 2048)         3147776     batch_normalization_611[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 2048)         0           dense_4[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 100)          204900      dropout_2[0][0]
# ==================================================================================================
# Total params: 57,695,556
# Trainable params: 3,355,748
# Non-trainable params: 54,339,808
# __________________________________________________________________________________________________

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %% [markdown]
# ## Train Model

# %%
history1 = model.fit(crop_train_generator, validation_data= crop_val_generator, epochs=50, verbose=True,  callbacks=[early_stop, rlrop])
# Out:
# Epoch 1/50
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# C:\Users\reonh\miniconda3\envs\dev\lib\site-packages\keras\engine\base_layer.py:1348: UserWarning: `layer.updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`layer.updates` will be removed in a future version. '

# %%
fig, axes = plt.subplots(1, 2, figsize=(20, 6))
axes[0].plot(history1.history['loss'])
axes[0].plot(history1.history['val_loss'])
axes[1].plot(history1.history['accuracy'])
axes[1].plot(history1.history['val_accuracy'])

# %%
history2 = model.fit(crop_train_generator, validation_data= crop_val_generator,epochs=50, verbose=True)
# Out:
# Epoch 1/50
# 331/331 [==============================] - 89s 269ms/step - loss: 0.9568 - accuracy: 0.7855 - top_k_categorical_accuracy: 0.9637 - val_loss: 2.1623 - val_accuracy: 0.5355 - val_top_k_categorical_accuracy: 0.7984
# Epoch 2/50
# 331/331 [==============================] - 103s 311ms/step - loss: 0.9566 - accuracy: 0.7902 - top_k_categorical_accuracy: 0.9635 - val_loss: 2.1832 - val_accuracy: 0.5471 - val_top_k_categorical_accuracy: 0.8073
# Epoch 3/50
# 331/331 [==============================] - 94s 282ms/step - loss: 0.9680 - accuracy: 0.7901 - top_k_categorical_accuracy: 0.9607 - val_loss: 2.2476 - val_accuracy: 0.5266 - val_top_k_categorical_accuracy: 0.7744
# Epoch 4/50
# 331/331 [==============================] - 87s 264ms/step - loss: 0.9407 - accuracy: 0.7922 - top_k_categorical_accuracy: 0.9642 - val_loss: 2.1608 - val_accuracy: 0.5560 - val_top_k_categorical_accuracy: 0.7869
# Epoch 5/50
# 331/331 [==============================] - 91s 274ms/step - loss: 0.9505 - accuracy: 0.7908 - top_k_categorical_accuracy: 0.9603 - val_loss: 2.2510 - val_accuracy: 0.5320 - val_top_k_categorical_accuracy: 0.7895
# Epoch 6/50
# 331/331 [==============================] - 101s 304ms/step - loss: 0.9208 - accuracy: 0.7973 - top_k_categorical_accuracy: 0.9685 - val_loss: 2.1995 - val_accuracy: 0.5302 - val_top_k_categorical_accuracy: 0.7895
# Epoch 7/50
# 331/331 [==============================] - 93s 280ms/step - loss: 0.9326 - accuracy: 0.7903 - top_k_categorical_accuracy: 0.9614 - val_loss: 2.1377 - val_accuracy: 0.5506 - val_top_k_categorical_accuracy: 0.8002
# Epoch 8/50
# 331/331 [==============================] - 90s 273ms/step - loss: 0.9117 - accuracy: 0.7986 - top_k_categorical_accuracy: 0.9676 - val_loss: 2.1079 - val_accuracy: 0.5471 - val_top_k_categorical_accuracy: 0.8002
# Epoch 9/50
# 331/331 [==============================] - 90s 273ms/step - loss: 0.9134 - accuracy: 0.7976 - top_k_categorical_accuracy: 0.9654 - val_loss: 2.2704 - val_accuracy: 0.5124 - val_top_k_categorical_accuracy: 0.7940
# Epoch 10/50
# 331/331 [==============================] - 92s 278ms/step - loss: 0.9317 - accuracy: 0.7935 - top_k_categorical_accuracy: 0.9626 - val_loss: 2.2522 - val_accuracy: 0.5275 - val_top_k_categorical_accuracy: 0.7842
# Epoch 11/50
# 331/331 [==============================] - 87s 264ms/step - loss: 0.9144 - accuracy: 0.7938 - top_k_categorical_accuracy: 0.9671 - val_loss: 2.2213 - val_accuracy: 0.5195 - val_top_k_categorical_accuracy: 0.7851
# Epoch 12/50
# 331/331 [==============================] - 90s 272ms/step - loss: 0.8998 - accuracy: 0.8024 - top_k_categorical_accuracy: 0.9648 - val_loss: 2.2625 - val_accuracy: 0.5302 - val_top_k_categorical_accuracy: 0.7922
# Epoch 13/50
# 331/331 [==============================] - 90s 270ms/step - loss: 0.9115 - accuracy: 0.7975 - top_k_categorical_accuracy: 0.9643 - val_loss: 2.1961 - val_accuracy: 0.5346 - val_top_k_categorical_accuracy: 0.7940
# Epoch 14/50
# 331/331 [==============================] - 88s 266ms/step - loss: 0.9171 - accuracy: 0.7978 - top_k_categorical_accuracy: 0.9621 - val_loss: 2.2552 - val_accuracy: 0.5293 - val_top_k_categorical_accuracy: 0.7824
# Epoch 15/50
# 331/331 [==============================] - 95s 287ms/step - loss: 0.9124 - accuracy: 0.7972 - top_k_categorical_accuracy: 0.9684 - val_loss: 2.2655 - val_accuracy: 0.5364 - val_top_k_categorical_accuracy: 0.7718
# Epoch 16/50
# 331/331 [==============================] - 90s 273ms/step - loss: 0.8884 - accuracy: 0.8012 - top_k_categorical_accuracy: 0.9676 - val_loss: 2.1591 - val_accuracy: 0.5444 - val_top_k_categorical_accuracy: 0.7957
# Epoch 17/50
# 331/331 [==============================] - 87s 263ms/step - loss: 0.8919 - accuracy: 0.8028 - top_k_categorical_accuracy: 0.9676 - val_loss: 2.1521 - val_accuracy: 0.5373 - val_top_k_categorical_accuracy: 0.7993
# Epoch 18/50
# 331/331 [==============================] - 87s 262ms/step - loss: 0.8953 - accuracy: 0.7986 - top_k_categorical_accuracy: 0.9668 - val_loss: 2.1332 - val_accuracy: 0.5515 - val_top_k_categorical_accuracy: 0.7975
# Epoch 19/50
# 331/331 [==============================] - 93s 280ms/step - loss: 0.8832 - accuracy: 0.8017 - top_k_categorical_accuracy: 0.9692 - val_loss: 2.1623 - val_accuracy: 0.5337 - val_top_k_categorical_accuracy: 0.7904
# Epoch 20/50
# 331/331 [==============================] - 87s 262ms/step - loss: 0.8875 - accuracy: 0.7997 - top_k_categorical_accuracy: 0.9661 - val_loss: 2.1620 - val_accuracy: 0.5453 - val_top_k_categorical_accuracy: 0.7966
# Epoch 21/50
# 331/331 [==============================] - 87s 263ms/step - loss: 0.8805 - accuracy: 0.8034 - top_k_categorical_accuracy: 0.9676 - val_loss: 2.1473 - val_accuracy: 0.5515 - val_top_k_categorical_accuracy: 0.7806
# Epoch 22/50
# 331/331 [==============================] - 87s 263ms/step - loss: 0.8794 - accuracy: 0.8003 - top_k_categorical_accuracy: 0.9688 - val_loss: 2.1219 - val_accuracy: 0.5400 - val_top_k_categorical_accuracy: 0.7975
# Epoch 23/50
# 331/331 [==============================] - 89s 267ms/step - loss: 0.8764 - accuracy: 0.8065 - top_k_categorical_accuracy: 0.9687 - val_loss: 2.1888 - val_accuracy: 0.5409 - val_top_k_categorical_accuracy: 0.7886
# Epoch 24/50
# 331/331 [==============================] - 91s 276ms/step - loss: 0.8753 - accuracy: 0.8066 - top_k_categorical_accuracy: 0.9669 - val_loss: 2.1967 - val_accuracy: 0.5293 - val_top_k_categorical_accuracy: 0.7895
# Epoch 25/50
# 331/331 [==============================] - 93s 281ms/step - loss: 0.8502 - accuracy: 0.8131 - top_k_categorical_accuracy: 0.9719 - val_loss: 2.1505 - val_accuracy: 0.5435 - val_top_k_categorical_accuracy: 0.7957
# Epoch 26/50
# 331/331 [==============================] - 87s 263ms/step - loss: 0.8853 - accuracy: 0.8052 - top_k_categorical_accuracy: 0.9672 - val_loss: 2.2368 - val_accuracy: 0.5471 - val_top_k_categorical_accuracy: 0.7815
# Epoch 27/50
# 331/331 [==============================] - 87s 262ms/step - loss: 0.8610 - accuracy: 0.8070 - top_k_categorical_accuracy: 0.9702 - val_loss: 2.1465 - val_accuracy: 0.5471 - val_top_k_categorical_accuracy: 0.7922
# Epoch 28/50
# 331/331 [==============================] - 86s 261ms/step - loss: 0.8650 - accuracy: 0.8093 - top_k_categorical_accuracy: 0.9706 - val_loss: 2.1418 - val_accuracy: 0.5595 - val_top_k_categorical_accuracy: 0.7851
# Epoch 29/50
# 331/331 [==============================] - 86s 261ms/step - loss: 0.8575 - accuracy: 0.8058 - top_k_categorical_accuracy: 0.9717 - val_loss: 2.2677 - val_accuracy: 0.5187 - val_top_k_categorical_accuracy: 0.7886
# Epoch 30/50
# 331/331 [==============================] - 88s 267ms/step - loss: 0.8551 - accuracy: 0.8094 - top_k_categorical_accuracy: 0.9675 - val_loss: 2.1353 - val_accuracy: 0.5417 - val_top_k_categorical_accuracy: 0.7975
# Epoch 31/50
# 331/331 [==============================] - 89s 268ms/step - loss: 0.8538 - accuracy: 0.8076 - top_k_categorical_accuracy: 0.9708 - val_loss: 2.1238 - val_accuracy: 0.5622 - val_top_k_categorical_accuracy: 0.7886
# Epoch 32/50
# 331/331 [==============================] - 88s 264ms/step - loss: 0.8627 - accuracy: 0.8091 - top_k_categorical_accuracy: 0.9686 - val_loss: 2.1110 - val_accuracy: 0.5382 - val_top_k_categorical_accuracy: 0.7860
# Epoch 33/50
# 331/331 [==============================] - 87s 261ms/step - loss: 0.8393 - accuracy: 0.8188 - top_k_categorical_accuracy: 0.9695 - val_loss: 2.1293 - val_accuracy: 0.5488 - val_top_k_categorical_accuracy: 0.8108
# Epoch 34/50
# 331/331 [==============================] - 86s 261ms/step - loss: 0.8399 - accuracy: 0.8154 - top_k_categorical_accuracy: 0.9709 - val_loss: 2.2131 - val_accuracy: 0.5409 - val_top_k_categorical_accuracy: 0.7851
# Epoch 35/50
# 331/331 [==============================] - 89s 268ms/step - loss: 0.8580 - accuracy: 0.8103 - top_k_categorical_accuracy: 0.9678 - val_loss: 2.1807 - val_accuracy: 0.5373 - val_top_k_categorical_accuracy: 0.7842
# Epoch 36/50
# 331/331 [==============================] - 87s 262ms/step - loss: 0.8410 - accuracy: 0.8130 - top_k_categorical_accuracy: 0.9690 - val_loss: 2.2272 - val_accuracy: 0.5568 - val_top_k_categorical_accuracy: 0.7780
# Epoch 37/50
# 331/331 [==============================] - 86s 259ms/step - loss: 0.8425 - accuracy: 0.8141 - top_k_categorical_accuracy: 0.9713 - val_loss: 2.1259 - val_accuracy: 0.5560 - val_top_k_categorical_accuracy: 0.7975
# Epoch 38/50
# 331/331 [==============================] - 83s 250ms/step - loss: 0.8485 - accuracy: 0.8126 - top_k_categorical_accuracy: 0.9696 - val_loss: 2.1559 - val_accuracy: 0.5533 - val_top_k_categorical_accuracy: 0.7966
# Epoch 39/50
# 331/331 [==============================] - 81s 245ms/step - loss: 0.8331 - accuracy: 0.8153 - top_k_categorical_accuracy: 0.9713 - val_loss: 2.1582 - val_accuracy: 0.5453 - val_top_k_categorical_accuracy: 0.7957
# Epoch 40/50
# 331/331 [==============================] - 82s 247ms/step - loss: 0.8542 - accuracy: 0.8030 - top_k_categorical_accuracy: 0.9709 - val_loss: 2.1283 - val_accuracy: 0.5551 - val_top_k_categorical_accuracy: 0.7975
# Epoch 41/50
# 331/331 [==============================] - 81s 245ms/step - loss: 0.8356 - accuracy: 0.8168 - top_k_categorical_accuracy: 0.9693 - val_loss: 2.1764 - val_accuracy: 0.5533 - val_top_k_categorical_accuracy: 0.7922
# Epoch 42/50
# 331/331 [==============================] - 81s 245ms/step - loss: 0.8526 - accuracy: 0.8077 - top_k_categorical_accuracy: 0.9706 - val_loss: 2.1400 - val_accuracy: 0.5409 - val_top_k_categorical_accuracy: 0.7895
# Epoch 43/50
# 331/331 [==============================] - 81s 245ms/step - loss: 0.8477 - accuracy: 0.8105 - top_k_categorical_accuracy: 0.9682 - val_loss: 2.2308 - val_accuracy: 0.5320 - val_top_k_categorical_accuracy: 0.7940
# Epoch 44/50
# 331/331 [==============================] - 81s 245ms/step - loss: 0.8382 - accuracy: 0.8135 - top_k_categorical_accuracy: 0.9714 - val_loss: 2.0976 - val_accuracy: 0.5391 - val_top_k_categorical_accuracy: 0.8082
# Epoch 45/50
# 331/331 [==============================] - 82s 247ms/step - loss: 0.8285 - accuracy: 0.8161 - top_k_categorical_accuracy: 0.9720 - val_loss: 2.1583 - val_accuracy: 0.5462 - val_top_k_categorical_accuracy: 0.7877
# Epoch 46/50
# 331/331 [==============================] - 87s 263ms/step - loss: 0.8431 - accuracy: 0.8092 - top_k_categorical_accuracy: 0.9697 - val_loss: 2.1548 - val_accuracy: 0.5391 - val_top_k_categorical_accuracy: 0.7931
# Epoch 47/50
# 331/331 [==============================] - 100s 303ms/step - loss: 0.8141 - accuracy: 0.8210 - top_k_categorical_accuracy: 0.9718 - val_loss: 2.2108 - val_accuracy: 0.5373 - val_top_k_categorical_accuracy: 0.7842
# Epoch 48/50
# 331/331 [==============================] - 97s 294ms/step - loss: 0.8378 - accuracy: 0.8172 - top_k_categorical_accuracy: 0.9693 - val_loss: 2.0996 - val_accuracy: 0.5622 - val_top_k_categorical_accuracy: 0.7957
# Epoch 49/50
# 331/331 [==============================] - 97s 293ms/step - loss: 0.8242 - accuracy: 0.8182 - top_k_categorical_accuracy: 0.9716 - val_loss: 2.2274 - val_accuracy: 0.5302 - val_top_k_categorical_accuracy: 0.7824
# Epoch 50/50
# 331/331 [==============================] - 98s 296ms/step - loss: 0.8272 - accuracy: 0.8159 - top_k_categorical_accuracy: 0.9710 - val_loss: 2.1708 - val_accuracy: 0.5480 - val_top_k_categorical_accuracy: 0.7833

# %%
fig, axes = plt.subplots(1, 2, figsize=(20, 6))
axes[0].plot(history2.history['loss'])
axes[0].plot(history2.history['val_loss'])
axes[1].plot(history2.history['accuracy'])
axes[1].plot(history2.history['val_accuracy'])

# %%
history3 =model.fit(crop_train_generator, validation_data= crop_val_generator, epochs=50, verbose=True,  callbacks=[early_stop, rlrop])
# Out:
# Epoch 1/50
# 331/331 [==============================] - 97s 293ms/step - loss: 0.8275 - accuracy: 0.8122 - top_k_categorical_accuracy: 0.9728 - val_loss: 2.2381 - val_accuracy: 0.5311 - val_top_k_categorical_accuracy: 0.8002
# Epoch 2/50
# 331/331 [==============================] - 97s 293ms/step - loss: 0.8246 - accuracy: 0.8171 - top_k_categorical_accuracy: 0.9724 - val_loss: 2.1610 - val_accuracy: 0.5409 - val_top_k_categorical_accuracy: 0.7886
# Epoch 3/50
# 331/331 [==============================] - 99s 297ms/step - loss: 0.8248 - accuracy: 0.8165 - top_k_categorical_accuracy: 0.9696 - val_loss: 2.2335 - val_accuracy: 0.5258 - val_top_k_categorical_accuracy: 0.7780
# Epoch 4/50
# 331/331 [==============================] - 99s 299ms/step - loss: 0.8215 - accuracy: 0.8205 - top_k_categorical_accuracy: 0.9706 - val_loss: 2.0918 - val_accuracy: 0.5488 - val_top_k_categorical_accuracy: 0.7975
# Epoch 5/50
# 331/331 [==============================] - 100s 302ms/step - loss: 0.8169 - accuracy: 0.8174 - top_k_categorical_accuracy: 0.9722 - val_loss: 2.1734 - val_accuracy: 0.5497 - val_top_k_categorical_accuracy: 0.7948
# Epoch 6/50
# 331/331 [==============================] - 91s 273ms/step - loss: 0.8121 - accuracy: 0.8160 - top_k_categorical_accuracy: 0.9724 - val_loss: 2.1454 - val_accuracy: 0.5382 - val_top_k_categorical_accuracy: 0.7913
# Epoch 7/50
# 331/331 [==============================] - 86s 258ms/step - loss: 0.8116 - accuracy: 0.8148 - top_k_categorical_accuracy: 0.9749 - val_loss: 2.0927 - val_accuracy: 0.5471 - val_top_k_categorical_accuracy: 0.8020
# Epoch 8/50
# 331/331 [==============================] - 85s 258ms/step - loss: 0.8148 - accuracy: 0.8214 - top_k_categorical_accuracy: 0.9755 - val_loss: 2.1854 - val_accuracy: 0.5444 - val_top_k_categorical_accuracy: 0.7975
# Epoch 9/50
# 331/331 [==============================] - 84s 255ms/step - loss: 0.8086 - accuracy: 0.8191 - top_k_categorical_accuracy: 0.9725 - val_loss: 2.1605 - val_accuracy: 0.5488 - val_top_k_categorical_accuracy: 0.7913
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 10/50
# 331/331 [==============================] - 82s 248ms/step - loss: 0.8008 - accuracy: 0.8212 - top_k_categorical_accuracy: 0.9742 - val_loss: 2.2319 - val_accuracy: 0.5231 - val_top_k_categorical_accuracy: 0.7913
# Epoch 11/50
# 331/331 [==============================] - 80s 243ms/step - loss: 0.7852 - accuracy: 0.8253 - top_k_categorical_accuracy: 0.9768 - val_loss: 2.0666 - val_accuracy: 0.5551 - val_top_k_categorical_accuracy: 0.8073
# Epoch 12/50
# 331/331 [==============================] - 82s 247ms/step - loss: 0.7871 - accuracy: 0.8299 - top_k_categorical_accuracy: 0.9742 - val_loss: 2.1407 - val_accuracy: 0.5435 - val_top_k_categorical_accuracy: 0.7957
# Epoch 13/50
# 331/331 [==============================] - 80s 243ms/step - loss: 0.7930 - accuracy: 0.8236 - top_k_categorical_accuracy: 0.9752 - val_loss: 2.1435 - val_accuracy: 0.5497 - val_top_k_categorical_accuracy: 0.7931
# Epoch 14/50
# 331/331 [==============================] - 80s 242ms/step - loss: 0.7828 - accuracy: 0.8307 - top_k_categorical_accuracy: 0.9749 - val_loss: 2.1028 - val_accuracy: 0.5471 - val_top_k_categorical_accuracy: 0.7957
# Epoch 15/50
# 331/331 [==============================] - 80s 242ms/step - loss: 0.7833 - accuracy: 0.8266 - top_k_categorical_accuracy: 0.9768 - val_loss: 2.0620 - val_accuracy: 0.5568 - val_top_k_categorical_accuracy: 0.8037
# Epoch 16/50
# 331/331 [==============================] - 80s 242ms/step - loss: 0.8129 - accuracy: 0.8198 - top_k_categorical_accuracy: 0.9715 - val_loss: 2.1312 - val_accuracy: 0.5488 - val_top_k_categorical_accuracy: 0.8091
# Epoch 17/50
# 331/331 [==============================] - 80s 242ms/step - loss: 0.7874 - accuracy: 0.8282 - top_k_categorical_accuracy: 0.9748 - val_loss: 2.1541 - val_accuracy: 0.5453 - val_top_k_categorical_accuracy: 0.7966
# Epoch 18/50
# 331/331 [==============================] - 81s 243ms/step - loss: 0.7867 - accuracy: 0.8263 - top_k_categorical_accuracy: 0.9773 - val_loss: 2.1413 - val_accuracy: 0.5631 - val_top_k_categorical_accuracy: 0.7975
# Epoch 19/50
# 331/331 [==============================] - 82s 247ms/step - loss: 0.7789 - accuracy: 0.8283 - top_k_categorical_accuracy: 0.9732 - val_loss: 2.1213 - val_accuracy: 0.5417 - val_top_k_categorical_accuracy: 0.7824
# Epoch 20/50
# 331/331 [==============================] - 82s 246ms/step - loss: 0.7982 - accuracy: 0.8204 - top_k_categorical_accuracy: 0.9751 - val_loss: 2.1616 - val_accuracy: 0.5417 - val_top_k_categorical_accuracy: 0.7815
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 21/50
# 331/331 [==============================] - 82s 248ms/step - loss: 0.7699 - accuracy: 0.8325 - top_k_categorical_accuracy: 0.9771 - val_loss: 2.1763 - val_accuracy: 0.5284 - val_top_k_categorical_accuracy: 0.7993
# Epoch 22/50
# 331/331 [==============================] - 81s 246ms/step - loss: 0.7658 - accuracy: 0.8354 - top_k_categorical_accuracy: 0.9765 - val_loss: 2.1190 - val_accuracy: 0.5622 - val_top_k_categorical_accuracy: 0.7886
# Epoch 23/50
# 331/331 [==============================] - 82s 247ms/step - loss: 0.7751 - accuracy: 0.8292 - top_k_categorical_accuracy: 0.9762 - val_loss: 2.1124 - val_accuracy: 0.5533 - val_top_k_categorical_accuracy: 0.8046
# Epoch 24/50
# 331/331 [==============================] - 82s 247ms/step - loss: 0.7691 - accuracy: 0.8339 - top_k_categorical_accuracy: 0.9731 - val_loss: 2.1143 - val_accuracy: 0.5586 - val_top_k_categorical_accuracy: 0.7940
# Epoch 25/50
# 331/331 [==============================] - 81s 246ms/step - loss: 0.7833 - accuracy: 0.8265 - top_k_categorical_accuracy: 0.9761 - val_loss: 2.0582 - val_accuracy: 0.5515 - val_top_k_categorical_accuracy: 0.8126
# Epoch 26/50
# 331/331 [==============================] - 83s 250ms/step - loss: 0.7758 - accuracy: 0.8318 - top_k_categorical_accuracy: 0.9741 - val_loss: 2.0976 - val_accuracy: 0.5533 - val_top_k_categorical_accuracy: 0.7993
# Epoch 27/50
# 331/331 [==============================] - 85s 256ms/step - loss: 0.7690 - accuracy: 0.8288 - top_k_categorical_accuracy: 0.9771 - val_loss: 2.1134 - val_accuracy: 0.5515 - val_top_k_categorical_accuracy: 0.7860
# Epoch 28/50
# 331/331 [==============================] - 83s 252ms/step - loss: 0.7756 - accuracy: 0.8275 - top_k_categorical_accuracy: 0.9744 - val_loss: 2.0579 - val_accuracy: 0.5480 - val_top_k_categorical_accuracy: 0.7957
# Epoch 29/50
# 331/331 [==============================] - 84s 253ms/step - loss: 0.7673 - accuracy: 0.8314 - top_k_categorical_accuracy: 0.9773 - val_loss: 2.0966 - val_accuracy: 0.5595 - val_top_k_categorical_accuracy: 0.7815
# Epoch 30/50
# 331/331 [==============================] - 84s 253ms/step - loss: 0.7567 - accuracy: 0.8364 - top_k_categorical_accuracy: 0.9771 - val_loss: 2.1626 - val_accuracy: 0.5355 - val_top_k_categorical_accuracy: 0.7877
# Epoch 31/50
# 331/331 [==============================] - 83s 252ms/step - loss: 0.7727 - accuracy: 0.8284 - top_k_categorical_accuracy: 0.9749 - val_loss: 2.1520 - val_accuracy: 0.5293 - val_top_k_categorical_accuracy: 0.7975
# Epoch 32/50
# 331/331 [==============================] - 84s 254ms/step - loss: 0.7590 - accuracy: 0.8343 - top_k_categorical_accuracy: 0.9772 - val_loss: 2.1438 - val_accuracy: 0.5329 - val_top_k_categorical_accuracy: 0.7860
# Epoch 33/50
# 331/331 [==============================] - 83s 250ms/step - loss: 0.7500 - accuracy: 0.8400 - top_k_categorical_accuracy: 0.9783 - val_loss: 2.1102 - val_accuracy: 0.5551 - val_top_k_categorical_accuracy: 0.7948
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# Epoch 34/50
# 331/331 [==============================] - 82s 247ms/step - loss: 0.7696 - accuracy: 0.8312 - top_k_categorical_accuracy: 0.9770 - val_loss: 2.1188 - val_accuracy: 0.5444 - val_top_k_categorical_accuracy: 0.8002
# Epoch 35/50
# 331/331 [==============================] - 82s 247ms/step - loss: 0.7548 - accuracy: 0.8373 - top_k_categorical_accuracy: 0.9749 - val_loss: 2.1654 - val_accuracy: 0.5480 - val_top_k_categorical_accuracy: 0.7957
# Epoch 36/50
# 331/331 [==============================] - 82s 247ms/step - loss: 0.7516 - accuracy: 0.8372 - top_k_categorical_accuracy: 0.9776 - val_loss: 2.1222 - val_accuracy: 0.5373 - val_top_k_categorical_accuracy: 0.8055
# Epoch 37/50
# 331/331 [==============================] - 82s 247ms/step - loss: 0.7617 - accuracy: 0.8314 - top_k_categorical_accuracy: 0.9763 - val_loss: 2.0917 - val_accuracy: 0.5560 - val_top_k_categorical_accuracy: 0.7948
# Epoch 38/50
# 331/331 [==============================] - 82s 248ms/step - loss: 0.7802 - accuracy: 0.8259 - top_k_categorical_accuracy: 0.9759 - val_loss: 2.1187 - val_accuracy: 0.5311 - val_top_k_categorical_accuracy: 0.7975
# Restoring model weights from the end of the best epoch.
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# Epoch 00038: early stopping

# %%
fig, axes = plt.subplots(1, 2, figsize=(20, 6))
axes[0].plot(history3.history['loss'])
axes[0].plot(history3.history['val_loss'])
axes[1].plot(history3.history['accuracy'])
axes[1].plot(history3.history['val_accuracy'])

# %% [markdown]
# ## Test on raw dataset without augmentation

# %%
no_augment_datagen=ImageDataGenerator(
        rescale=1./255,
        fill_mode='nearest')

train_crop_no_augment = no_augment_datagen.flow_from_directory(
    directory="./UECFOOD100_CROP/train_crop",
    batch_size=32,
    seed=42,
    shuffle=False,
    class_mode="categorical",
    target_size=(128,128))

test_crop_no_augment = no_augment_datagen.flow_from_directory(
    directory="./UECFOOD100_CROP/test_crop",
    batch_size=32,
    seed=42,
    shuffle=False,
    class_mode="categorical",
    target_size=(128,128),
    subset='training')
# Out:
# Found 11688 images belonging to 100 classes.
# Found 2922 images belonging to 100 classes.

# %%
model.evaluate(train_crop_no_augment)
# Out:
# 366/366 [==============================] - 40s 108ms/step - loss: 0.5924 - accuracy: 0.9019 - top_k_categorical_accuracy: 0.9801
# [0.5923793315887451, 0.9018651843070984, 0.9800650477409363]

# %%
model.evaluate(test_crop_no_augment)
# Out:
# 92/92 [==============================] - 11s 114ms/step - loss: 1.6399 - accuracy: 0.6400 - top_k_categorical_accuracy: 0.8734
# [1.6399325132369995, 0.6399726271629333, 0.8733744025230408]

# %%
model.save('uec100')
# Out:
# INFO:tensorflow:Assets written to: uec100\assets

# %% [markdown]
# ## Convert Classifier to Object Detector

# %%
def sliding_window(image, step, ws):
    # slide a window across the image
    for y in range(0, image.shape[0] - ws[1], step):
        for x in range(0, image.shape[1] - ws[0], step):
            # yield the current window
            yield (x, y, image[y:y + ws[1], x:x + ws[0]])
            
def image_pyramid(image, scale=1.5, minSize=(224, 224)):
    # yield the original image
    yield image
    # keep looping over the image pyramid
    while True:
        # compute the dimensions of the next image in the pyramid
        w = int(image.shape[1] / scale)
        image = cv2.resize(image, (w,w))
        if image.shape[0] < minSize[1] or image.shape[1] < minSize[0]:
            break
        # yield the next image in the pyramid
        yield image

# %%
def non_max_suppression(boxes, probs=None, overlapThresh=0.1):
    # if there are no boxes, return an empty list
    if len(boxes) == 0:
        return []

    # if the bounding boxes are integers, convert them to floats -- this
    # is important since we'll be doing a bunch of divisions
    if boxes.dtype.kind == "i":
        boxes = boxes.astype("float")

    # initialize the list of picked indexes
    pick = []

    # grab the coordinates of the bounding boxes
    x1 = boxes[:, 0]
    y1 = boxes[:, 1]
    x2 = boxes[:, 2]
    y2 = boxes[:, 3]

    # compute the area of the bounding boxes and grab the indexes to sort
    # (in the case that no probabilities are provided, simply sort on the
    # bottom-left y-coordinate)
    area = (x2 - x1 + 1) * (y2 - y1 + 1)
    idxs = area

    # if probabilities are provided, sort on them instead
    if probs is not None:
        idxs = probs

    # sort the indexes
    idxs = np.argsort(idxs)

    # keep looping while some indexes still remain in the indexes list
    while len(idxs) > 0:
        # grab the last index in the indexes list and add the index value
        # to the list of picked indexes
        last = len(idxs) - 1
        i = idxs[last]
        pick.append(i)

        # find the largest (x, y) coordinates for the start of the bounding
        # box and the smallest (x, y) coordinates for the end of the bounding
        # box
        xx1 = np.maximum(x1[i], x1[idxs[:last]])
        yy1 = np.maximum(y1[i], y1[idxs[:last]])
        xx2 = np.minimum(x2[i], x2[idxs[:last]])
        yy2 = np.minimum(y2[i], y2[idxs[:last]])

        # compute the width and height of the bounding box
        w = np.maximum(0, xx2 - xx1 + 1)
        h = np.maximum(0, yy2 - yy1 + 1)

        # compute the ratio of overlap
        overlap = (w * h) / area[idxs[:last]]

        # delete all indexes from the index list that have overlap greater
        # than the provided overlap threshold
        idxs = np.delete(idxs, np.concatenate(([last],
            np.where(overlap > overlapThresh)[0])))

    # return only the bounding boxes that were picked
    return boxes[pick].astype("int")

# %%
def detect_food(img):
    WIDTH = 128
    PYR_SCALE = 1.5
    WIN_STEP = 16
    ROI_SIZE = (128,128)
    INPUT_SIZE = (128, 128)
    rois = []
    locs = []
    (H, W) = img.shape[:2]
    pyramid = image_pyramid(img, minSize=(128,128))
    for image in pyramid:
        scale = W / float(image.shape[1])
        for (x, y, roiOrig) in sliding_window(image, WIN_STEP, ROI_SIZE):
            x = int(x * scale)
            y = int(y * scale)
            w = int(ROI_SIZE[0] * scale)
            h = int(ROI_SIZE[1] * scale)
            roi = cv2.resize(roiOrig, INPUT_SIZE)
            roi = img_to_array(roi)
            rois.append(roi)
            locs.append((x, y, x + w, y + h))
            
    import time
    # convert the ROIs to a NumPy array
    rois = np.array(rois, dtype="float32")
    # classify each of the proposal ROIs and print how long the classifications took
    print("[INFO] classifying ROIs...")
    start = time.time()
    preds = model.predict(rois)
    end = time.time()
    print("[INFO] classifying ROIs took {:.5f} seconds".format(
        end - start))
    
    bbox_predictions = {}

    for i, p in enumerate(preds):
        # grab the prediction information for the current ROI
        predicted_label = np.argmax(p)

        # filter out weak detections by ensuring the predicted probability
        # is greater than the minimum probability
        if p[predicted_label] >= 0.995:

            # grab the bounding box associated with the prediction and
            # convert the coordinates
            box = locs[i]
            predicted_label_text = text_labels.iloc[predicted_label][0]

            L = bbox_predictions.get(predicted_label_text, [])
            L.append((box, p[predicted_label]))
            bbox_predictions[predicted_label_text] = L
    
    clone = img.copy()

    for item in bbox_predictions.keys():
        
        boxes = np.array([p[0] for p in bbox_predictions[item]])
        proba = np.array([p[1] for p in bbox_predictions[item]])
        boxes = non_max_suppression(boxes,proba)
        
        print('[FOOD DETECTED] ' +  item + ' ' + str(proba.max()))
        for (startX, startY, endX, endY) in boxes:
            # draw the bounding box and label on the image
            cv2.rectangle(clone, (startX, startY), (endX, endY),(0, 255, 0), 2)
            y = startY - 10 if startY - 10 > 10 else startY + 10
            cv2.putText(clone, item, (startX, y),
                cv2.FONT_HERSHEY_SIMPLEX, 0.45, (0, 255, 0), 2)
            break
            
    plt.imshow(np.clip(clone, a_max = 1, a_min=0))

# %% [markdown]
# ## Exploration on accuracy

# %%
ytrue =test_crop_no_augment.classes
ypred = model.predict(test_crop_no_augment)
ypred_label = [np.argmax(pred) for pred in ypred]

# %%
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc
matrix = confusion_matrix(ytrue, ypred_label)
class_accuracies = matrix.diagonal()/matrix.sum(axis=1)
plt.style.use('classic')
plt.title('Class Accuracy Histogram')
p = plt.hist(class_accuracies, bins=20)

# %%
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(100):
    fpr[i], tpr[i], _ = roc_curve(np.array(pd.get_dummies(ytrue))[:, i], ypred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# %%
from scipy import interp
from itertools import cycle
lw = 2
n_classes = 100


# First aggregate all false positive rates
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

# Then interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += interp(all_fpr, fpr[i], tpr[i])

# Finally average it and compute AUC
mean_tpr /= n_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])


plt.plot(fpr["macro"], tpr["macro"],
         label='macro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["macro"]),
         color='navy', linestyle=':', linewidth=4)

colors = cycle(['aqua', 'darkorange', 'cornflowerblue'])
# for i, color in zip(range(n_classes), colors):
#     plt.plot(fpr[i], tpr[i], color=color, lw=lw,
#              label='ROC curve of class {0} (area = {1:0.2f})'
#              ''.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Some extension of Receiver operating characteristic to multi-class')
plt.legend(loc="lower right")
plt.show()
# Out:
# C:\Users\reonh\AppData\Local\Temp/ipykernel_33176/4213337631.py:13: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
#   mean_tpr += interp(all_fpr, fpr[i], tpr[i])

# %% [markdown]
# ## Try random images

# %%
class_labels = pd.read_csv('./UECFOOD100_CROP/category.txt', sep='\t')
class_labels.id = class_labels.id.astype(str)
class_labels = class_labels.sort_values('id')
# Out:
#      id                     name
# 0     1                     rice
# 1     2             eels on rice
# 2     3                    pilaf
# 3     4  chicken-'n'-egg on rice
# 4     5      pork cutlet on rice
# ..  ...                      ...
# 95   96          dipping noodles
# 96   97                  hot dog
# 97   98             french fries
# 98   99               mixed rice
# 99  100            goya chanpuru
#
# [100 rows x 2 columns]

# %%
img =load_img('web_pics/friedrice.jpg', target_size=(128,128))
preds = model.predict(np.array([img_to_array(img)/255]))
print(class_labels.iloc[np.argmax(preds[0])])
img
# Out:
# name    fried rice
# Name: 9, dtype: object
# <PIL.Image.Image image mode=RGB size=128x128 at 0x1E18DF32B50>

# %%
img = load_img('web_pics/fastfood_meal.jpg')
img = img_to_array(img)/255
detect_food(img)
# Out:
# [INFO] classifying ROIs...
# [INFO] classifying ROIs took 6.88099 seconds
# [FOOD DETECTED] french fries 0.99998045
# [FOOD DETECTED] hamburger 0.99997056
